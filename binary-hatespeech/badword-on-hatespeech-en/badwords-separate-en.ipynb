# %%
import pandas as pd
import torch
from transformers import pipeline

# Check if GPU is available, and set device accordingly
device = 0 if torch.cuda.is_available() else -1

# Load the dataset
df = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/final_preprocessed_data_yidong_devansh.csv', header=None, names=['text', 'hs_class'])

df['text'] = df['text'].astype(str)
df['hs_class'] = pd.to_numeric(df['hs_class'], errors='coerce')

df.dropna(subset=['hs_class'], inplace=True)

df['hs_class'] = df['hs_class'].astype(int)
df['hs_class'] = df['hs_class'].map({1: 'positive', 0: 'negative'})

# %%
# Read sexual-related words from a txt file
def load_sexual_words(file_path):
    with open(file_path, 'r') as file:
        # Strip newline characters and any extra spaces
        words = [line.strip() for line in file.readlines()]
    return words

# Load the sexual words from the text file
sexual_words = load_sexual_words("/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/misc/sex-vocab.txt")

# Function to check if text contains any sexual-related word
def contains_sexual_words(text):
    return any(word in text.lower() for word in sexual_words)

# %%
# # Filter out positive rows containing sexual-related words
# positive_df = df[df['hs_class'] == 'positive']
# positive_with_sexual_words = positive_df[positive_df['text'].apply(contains_sexual_words)]

# # Save the new dataset containing the positive hate speech with sexual-related words
# positive_with_sexual_words.to_csv("positive_hatespeech_with_sexual_words.csv", index=False)

# # Display the filtered dataset
# positive_with_sexual_words

# # Filter out positive rows that do NOT contain sexual-related words
# positive_df = df[df['hs_class'] == 'positive']
# positive_without_sexual_words = positive_df[~positive_df['text'].apply(contains_sexual_words)]  # Use `~` to negate the condition

# # Save the new dataset containing the positive hate speech that does NOT have sexual-related words
# positive_without_sexual_words.to_csv("positive_hatespeech_without_sexual_words.csv", index=False)

# # Display the filtered dataset
# positive_without_sexual_words

# Filter out negative rows containing sexual-related words
negative_df = df[df['hs_class'] == 'negative']
negative_with_sexual_words = negative_df[negative_df['text'].apply(contains_sexual_words)]

# Save the new dataset containing the positive hate speech with sexual-related words
negative_with_sexual_words.to_csv("negative_hatespeech_with_sexual_words.csv", index=False)

# Display the filtered dataset
negative_with_sexual_words

# # Filter out negative rows that do NOT contain sexual-related words
# negative_df = df[df['hs_class'] == 'negative']
# negative_without_sexual_words = negative_df[~negative_df['text'].apply(contains_sexual_words)]  # Use `~` to negate the condition

# # Save the new dataset containing the positive hate speech that does NOT have sexual-related words
# negative_without_sexual_words.to_csv("negative_hatespeech_without_sexual_words.csv", index=False)

# # Display the filtered dataset
# negative_without_sexual_words
# Out:
#                                                      text  hs_class
# 545     randy black is an expert all right he teaches ...  negative
# 550     dr albert schweitzer s two hour documentary fr...  negative
# 554     he what a slut checking her lines bad actors c...  negative
# 556     i what a slut a right sector supporter but it ...  negative
# 559     i remember after the boston marathon bombings ...  negative
# ...                                                   ...       ...
# 451696  wrestling arenas i am going to make a deal wit...  negative
# 451698  chadbryant strikes again this did not take lon...  negative
# 451699  i do not see you argument rho bite facts art t...  negative
# 451701  forget it nothing against you but i will have ...  negative
# 451707  i have unblocked you eddie as i discussed on u...  negative
#
# [130270 rows x 2 columns]

# %%
import pandas as pd

pos_df2 = (pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/positive_hatespeech_without_sexual_words.csv')).sample(frac=0.1, random_state=42)

# Display the sampled DataFrame
print(pos_df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4303 entries, 36471 to 26871
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      4303 non-null   object
#  1   hs_class  4303 non-null   object
# dtypes: object(2)
# memory usage: 100.9+ KB
# None

# %%
import pandas as pd

pos_df1 = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/positive_hatespeech_with_sexual_words.csv')
pos_df2 = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/positive_hatespeech_without_sexual_words.csv')

pos_df1.rename(columns={"hs_class": "all_positive_label"})
pos_df2.rename(columns={"hs_class": "all_positive_label"})

# Display the sampled DataFrame
print(pos_df1.info())
print(pos_df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37220 entries, 0 to 37219
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      37220 non-null  object
#  1   hs_class  37220 non-null  object
# dtypes: object(2)
# memory usage: 581.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43030 entries, 0 to 43029
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      43030 non-null  object
#  1   hs_class  43030 non-null  object
# dtypes: object(2)
# memory usage: 672.5+ KB
# None

# %%
import pandas as pd
from deep_translator import GoogleTranslator

# Load the CSV file
df = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/data_preprocessed.csv')

# Initialize the translator
translator = GoogleTranslator(source='id', target='en')

# Function to translate text
def translate_text(text):
    try:
        return translator.translate(text)
    except Exception as e:
        print(f"Error translating: {text} - {e}")
        return text  # Return original text if translation fails

# Apply the translation to the 'text' column
df['text_translated'] = df['text'].apply(translate_text)

# Save the translated DataFrame to a new CSV
df.to_csv('data_preprocessed_en_translated.csv', index=False)

print("Translation complete. Saved as 'data_preprocessed_en_translated.csv'")
# Out:
# Error translating: kejar setor bangsat rupiah turun  - HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=id&q=kejar+setor+bangsat+rupiah+turun (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fda34345b40>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# Error translating: nan - nan --> text must be a valid text with maximum 5000 character,otherwise it cannot be translated
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 19
#      16         return text  # Return original text if translation fails
#      18 # Apply the translation to the 'text' column
# ---> 19 df['text_translated'] = df['text'].apply(translate_text)
#      21 # Save the translated DataFrame to a new CSV
#      22 df.to_csv('data_preprocessed_en_translated.csv', index=False)
#
# ...

# %%
import pandas as pd
import csv

# Load the dataset
df = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/data_preprocessed_en_translated.csv', quoting=csv.QUOTE_ALL)

# Keep only the relevant columns (English text and hs_class)
df = df[['text_translated', 'hs_class']]

# Rename columns to match the desired format
df = df.rename(columns={'text_translated': 'text'})

df['text'] = df['text'].str.replace('"', '', regex=False)  # Remove internal quotes if any

# Save the new CSV with the correct format
df.to_csv('data_preprocessed_en_translated_formatted.csv', index=False)

df.info()

print("Dataset has been formatted and saved as 'data_preprocessed_en_translated_formatted.csv'.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11103 entries, 0 to 11102
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      11062 non-null  object
#  1   hs_class  11103 non-null  object
# dtypes: object(2)
# memory usage: 173.6+ KB
# Dataset has been formatted and saved as 'data_preprocessed_en_translated_formatted.csv'.

# %%
import csv
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler

# hs_class is 'negative' WITHOUT SEXUAL WORD 
neg_df1 = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/negative_hatespeech_without_sexual_words.csv')

# hs_class is 'negative' WITH SEXUAL WORD 
neg_df = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/negative_hatespeech_with_sexual_words.csv')

# hs_class is 'positive' WITH SEXUAL WORD 
pos_df1 = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/positive_hatespeech_with_sexual_words.csv')

# hs_class is 'positive' WITHOUT SEXUAL WORD 
pos_df = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/positive_hatespeech_without_sexual_words.csv')

val_df = pd.concat([neg_df1, pos_df1, neg_df, pos_df], ignore_index=True)

# Undersample using imbalanced-learn
# Create the undersampling object
undersampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)

# Separate the features (X) and the target (y)
X = val_df['text'].values.reshape(-1, 1)  # Reshape required because RandomUnderSampler expects a 2D array
y = val_df['hs_class']

# Perform the undersampling
X_resampled, y_resampled = undersampler.fit_resample(X, y)

# Create a new dataframe with the resampled data
val_df = pd.DataFrame({'text': X_resampled.flatten(), 'hs_class': y_resampled}) # df here is already resampled

val_df = val_df.sample(frac=0.15, random_state=42)

# Save the new CSV with the correct format
val_df.to_csv('val_df.csv', index=False)

val_df.info()
print(val_df['hs_class'].value_counts())

print("Dataset has been formatted and saved as 'val_df.csv'.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24075 entries, 46322 to 122434
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      24075 non-null  object
#  1   hs_class  24075 non-null  object
# dtypes: object(2)
# memory usage: 564.3+ KB
# hs_class
# positive    12125
# negative    11950
# Name: count, dtype: int64
# Dataset has been formatted and saved as 'val_df.csv'.

# %%
import pandas as pd

df = pd.read_csv('/nas.dbms/fathan/test/multilang-hate-models/binary-hatespeech/badword-on-hatespeech-en/val_df.csv')

df.info()
# Generate pie chart for 'hs_class' labels
class_counts = df['hs_class'].value_counts()

print(class_counts)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24075 entries, 0 to 24074
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      24075 non-null  object
#  1   hs_class  24075 non-null  object
# dtypes: object(2)
# memory usage: 376.3+ KB
# hs_class
# positive    12125
# negative    11950
# Name: count, dtype: int64
